# %% [markdown]
# # Write data transformations using sklearn pipeline

# %%
import numpy as np
import pandas as pd
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class DataGrabber(BaseEstimator, TransformerMixin):
  """
  Returns the different feature names
  """
  def __init__(self, url):
    self.url = url
    pass

  def fit(self, X, y):
    return self
  
  def transform(self, _):
    return pd.read_excel(self.url)

# %%
class ColumnRenamer(BaseEstimator, TransformerMixin):
  """
  Renames dict columns
  """
  def __init__(self, columns):
    self.columns = columns
    pass

  def fit(self, X, y):
    return self
  
  def transform(self, df):
    return df.rename(columns=self.columns)

# %%
class ColumnReformatter(BaseEstimator, TransformerMixin):
  """
  Renames dict columns
  """
  def __init__(self, columns_funs):
    self.columns_funs = columns_funs
    pass

  def fit(self, X, y):
    return self
  
  def transform(self, df):
    for column, fun in self.columns_funs.items():
      df[column] = df[column].apply(fun)
    return df

# %%
class CandidateFlatMapper(BaseEstimator, TransformerMixin):
  """
  Flatmaps a row with n candidates to n rows
  """
  def __init__(self):
    pass

  def fit(self, X, y):
    return self
  
  def _flatten(self, df_x):
    d = {'candidate_party': [], 'votes': []}
    tups = [("BName{0}".format(i), "Tally{0}".format(i)) for i in range(1,11)]
    for name, tally in tups:
        d['candidate_party'].extend(df_x[name])
        d['votes'].extend(df_x[tally])
    return pd.DataFrame(d)
  
  def transform(self, df):
    out = df.groupby(["county", "precinct", "office", "district", "Candidate Group"])\
      .apply(self._flatten).reset_index()
    out = out.dropna(subset=["candidate_party"])
    return out

# %%
import re

class CandidatePartySplitter(BaseEstimator, TransformerMixin):
  def __init__(self):
    self.writein_cand = re.compile(r"^\.\s(Write-in)\s-\s(.*)")
    self.cand_party = re.compile(r"^\.\s(.*)\s-\s([A-Z]?)$")
    self.cand = re.compile(r"^\.\s(.*)$")
    pass

  def fit(self, X, y):
    return self
  
  def get_candidate_party(self, s):
    if not isinstance(s, str):
      print(s)
      print(type(s))
      raise ValueError("Unrecognized input format")
      
    m_wi = self.writein_cand.match(s)
    m_cp = self.cand_party.match(s)
    m_c  = self.cand.match(s)
    if m_wi is not None:
      party, name = m_wi.groups()
      return (name, party)
    elif m_cp is not None:
      name, party = m_cp.groups()
      return (name, party)
    elif m_c is not None:
      name = m_c.groups()[0]
      return (name, "")
    else:
      print(s)
      raise ValueError("Unrecognized input string format")
  
  def transform(self, df):
    df["candidate"], df["party"] = zip(*df.candidate_party.map(self.get_candidate_party))
    return df

# %%
from nameparser import HumanName

class CandidateToCategorical(BaseEstimator, TransformerMixin):
  def __init__(self):
    pass
  
  def fit(self, X, y):
    return self

  def name_mapper(self, s):
    name = HumanName(s)
    return "{last}{suffix}, {first}".format(
      **dict(last=name.last, suffix=name.suffix, first=name.first)
    )
  
  def transform(self, df):
    cands = pd.Series(df.candidate.unique())
    categories = cands.loc[cands.map(self.name_mapper).sort_values().index]
    df["candidate"] = pd.Categorical(df.candidate, 
                                     categories=categories).map(lambda s: s.replace(",",""))
    return df

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline([
    ("grab_data", DataGrabber("http://share.tn.gov/sos/election/results/2010-11/November2010.xls")),
    ("rename_columns", ColumnRenamer({
            "District":"district",
            "COUNTY":"county",
            "OFFICENAME":"office",
            "Precinct Sequence":"precinct"
          })
    ),
    ("reformat_columns", ColumnReformatter({"county": lambda s: s.capitalize()})),
    ("rectify_candidates", CandidateFlatMapper()),
    ("split_candidate_party", CandidatePartySplitter()),
    ("categorical_candidates", CandidateToCategorical()),
  ])

# %%
df = pipe.transform(pd.DataFrame())

# %%
df.sort_values("candidate")
# Out:
#            county  precinct                                       office  \
# 50471    Sullivan         1  Tennessee House of Representatives District
# 50561    Sullivan         5  Tennessee House of Representatives District
# 50591    Sullivan         6  Tennessee House of Representatives District
# 50641    Sullivan         8  Tennessee House of Representatives District
# 50671    Sullivan         9  Tennessee House of Representatives District
# 50691    Sullivan        10  Tennessee House of Representatives District
# 50991    Sullivan        22  Tennessee House of Representatives District
# 51011    Sullivan        23  Tennessee House of Representatives District
# 51041    Sullivan        24  Tennessee House of Representatives District
# 51091    Sullivan        26  Tennessee House of Representatives District
# 51111    Sullivan        27  Tennessee House of Representatives District
# 51141    Sullivan        28  Tennessee House of Representatives District
# 50531    Sullivan         4  Tennessee House of Representatives District
# 51161    Sullivan        29  Tennessee House of Representatives District
# 27831     Johnson        12  Tennessee House of Representatives District
# 27811     Johnson        11  Tennessee House of Representatives District
# 27611     Johnson         1  Tennessee House of Representatives District
# 27791     Johnson        10  Tennessee House of Representatives District
# 27771     Johnson         9  Tennessee House of Representatives District
# 27751     Johnson         8  Tennessee House of Representatives District
# 27731     Johnson         7  Tennessee House of Representatives District
# 27711     Johnson         6  Tennessee House of Representatives District
# 27631     Johnson         2  Tennessee House of Representatives District
# 27651     Johnson         3  Tennessee House of Representatives District
# 27691     Johnson         5  Tennessee House of Representatives District
# 27851     Johnson        13  Tennessee House of Representatives District
# 50491    Sullivan         2  Tennessee House of Representatives District
# 27671     Johnson         4  Tennessee House of Representatives District
# 15770    Franklin        14  Tennessee House of Representatives District
# 15730    Franklin        12  Tennessee House of Representatives District
# ...           ...       ...                                          ...
# 17095       Giles         5      U. S. House of Representatives District
# 26175     Hickman        12      U. S. House of Representatives District
# 7855   Cumberland        20      U. S. House of Representatives District
# 56105       White        24      U. S. House of Representatives District
# 26205     Hickman        13      U. S. House of Representatives District
# 40585       Roane         8      U. S. House of Representatives District
# 56015       White        21      U. S. House of Representatives District
# 37775      Morgan         6      U. S. House of Representatives District
# 40625       Roane        10      U. S. House of Representatives District
# 40645       Roane        11      U. S. House of Representatives District
# 26335     Hickman        17      U. S. House of Representatives District
# 40705       Roane        14      U. S. House of Representatives District
# 40725       Roane        15      U. S. House of Representatives District
# 56045       White        22      U. S. House of Representatives District
# 40745       Roane        16      U. S. House of Representatives District
# 40765       Roane        17      U. S. House of Representatives District
# 26305     Hickman        16      U. S. House of Representatives District
# 40805       Roane        19      U. S. House of Representatives District
# 40825       Roane        20      U. S. House of Representatives District
# 40845       Roane        21      U. S. House of Representatives District
# 26245     Hickman        14      U. S. House of Representatives District
# 40865       Roane        22      U. S. House of Representatives District
# 40845       4.0                1        5      . Gerald York - I      6
# 26245       4.0                1        5      . Gerald York - I      2
# 40865       4.0                1        5      . Gerald York - I      6
# 40885       4.0                1        5      . Gerald York - I      7
# 40905       4.0                1        5      . Gerald York - I     15
# 56075       4.0                1        5      . Gerald York - I     11
# 3305        4.0                1        5      . Gerald York - I      1
# 3285        4.0                1        5      . Gerald York - I      3
# 3265        4.0                1        5      . Gerald York - I      2
# 3245        4.0                1        5      . Gerald York - I      0
# 18825       4.0                1        5      . Gerald York - I      0
#
#              candidate party
# 50471   Joe Mike Akard     D
# 50561   Joe Mike Akard     D
# 50591   Joe Mike Akard     D
# 50641   Joe Mike Akard     D
# 50671   Joe Mike Akard     D
# 50691   Joe Mike Akard     D
# 50991   Joe Mike Akard     D
# 51011   Joe Mike Akard     D
# 51041   Joe Mike Akard     D
# 51091   Joe Mike Akard     D
# 51111   Joe Mike Akard     D
# 51141   Joe Mike Akard     D
# 50531   Joe Mike Akard     D
# 51161   Joe Mike Akard     D
# 27831   Joe Mike Akard     D
# 27811   Joe Mike Akard     D
# 27611   Joe Mike Akard     D
# 27791   Joe Mike Akard     D
# 27771   Joe Mike Akard     D
# 27751   Joe Mike Akard     D
# 27731   Joe Mike Akard     D
# 27711   Joe Mike Akard     D
# 27631   Joe Mike Akard     D
# 27651   Joe Mike Akard     D
# 27691   Joe Mike Akard     D
# 27851   Joe Mike Akard     D
# 50491   Joe Mike Akard     D
# 27671   Joe Mike Akard     D
# 15770  David Alexander     R
# 15730  David Alexander     R
# ...                ...   ...
# 17095      Gerald York     I
# 26175      Gerald York     I
# 7855       Gerald York     I
# 56105      Gerald York     I
# 26205      Gerald York     I
# 40585      Gerald York     I
# 56015      Gerald York     I
# 37775      Gerald York     I
# 40625      Gerald York     I
# 40645      Gerald York     I
# 26335      Gerald York     I
# 40705      Gerald York     I
# 40725      Gerald York     I
# 56045      Gerald York     I
# 40745      Gerald York     I
# 40765      Gerald York     I
# 26305      Gerald York     I
# 40805      Gerald York     I
# 40825      Gerald York     I
# 40845      Gerald York     I
# 26245      Gerald York     I
# 40865      Gerald York     I
# 40885      Gerald York     I
# 40905      Gerald York     I
# 56075      Gerald York     I
# 3305       Gerald York     I
# 3285       Gerald York     I
# 3265       Gerald York     I
# 3245       Gerald York     I
# 18825      Gerald York     I
#
# [19938 rows x 10 columns]

# %%
for office in df.office.unique():
  df.loc[df.office == office, :].groupby(["county", "candidate", "party", "office", "district"]).agg({
      "votes": np.sum,
    }).reset_index().sort_values(["candidate", "county"])\
  .to_csv(re.sub(r"\s+", "_", office)+".csv", index=False)

# %%
df.loc[df.candidate == "D.H. (Andy) Andrew",:]
# Out:
#        county  precinct                                   office  district  \
# 1682   Blount         1  U. S. House of Representatives District       2.0
# 1702   Blount         2  U. S. House of Representatives District       2.0
# 1722   Blount         3  U. S. House of Representatives District       2.0
# 1742   Blount         4  U. S. House of Representatives District       2.0
# 1762   Blount         5  U. S. House of Representatives District       2.0
# 1782   Blount         6  U. S. House of Representatives District       2.0
